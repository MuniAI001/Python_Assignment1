# %% [markdown]
# <a href="https://colab.research.google.com/github/MuniAI001/Python_Assignment1/blob/main/extra_assignment_level_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Extra Assignment-level-1-python

# %% [markdown]
# print Statement
# expected output: HOPE AI

# %%
print("HOPE AI")
# Out:
# HOPE AI

# %% [markdown]
#  # Buy input
#  Exp op: Enter your institute name? : HOPE AI

# %%
Inst_name = input("Enter your institute name? :")
# Out:
# Enter your institute name? :HOPE AI

# %% [markdown]
# #Buy inputs
# EXP OP:
# Enter your name: Raj
# Enter your age: 15
# Enter your school name: Guru school
# Enter your drgree: B.E CSE

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
school_nm = input("Enter your school name: ")
degree = input("Enter your drgree: ")
# Out:
# Enter your name: Raj
# Enter your age: 25
# Enter your school name: GHSS
# Enter your drgree: B.E CSE

# %% [markdown]
#  #Addition

# %%
a=int(input("a= "))
b=int(input("b= "))
add = a + b
print("add= ",add)
# Out:
# a= 24
# b= 21
# add=  45

# %% [markdown]
# #Subtraction

# %%
a=int(input("a= "))
b=int(input("b= "))
sub = a - b
print("Sub = ",sub)
# Out:
# a= 25
# b= 10
# Sub =  15

# %% [markdown]
# #Multiplication

# %%
a=int(input("a= "))
b=int(input("b= "))
mul = a * b
print("Mul = ",mul)
# Out:
# a= 3
# b= 10
# Mul =  30

# %% [markdown]
# #Division

# %%
a=int(input("a= "))
b=int(input("b= "))
div = a / b
print("div = ",div)
# Out:
# a= 76
# b= 31
# div =  2.4516129032258065

# %% [markdown]
# #Floor Division

# %%
a=int(input("a= "))
b=int(input("b= "))
div = int(a / b)
print("div = ",div)
# Out:
# a= 76
# b= 31
# div =  2

# %% [markdown]
# #Madulo

# %%
a=int(input("a= "))
b=int(input("b= "))
mod = int(a % b)
print("mod = ",mod)
# Out:
# a= 76
# b= 31
# mod =  14

# %% [markdown]
# #Power

# %%
a=int(input("a= "))
b=int(input("b= "))
pwr = int(a ** b)
print("pwr = ",pwr)
# Out:
# a= 4
# b= 4
# pwr =  256
