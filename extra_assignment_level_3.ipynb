# %% [markdown]
# <a href="https://colab.research.google.com/github/MuniAI001/Python_Assignment1/blob/main/extra_assignment_level_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Extra assignment level - 3.

# %%
inp=int(input("value: "))
if inp==10:
  print("Correct")
# Out:
# value: 10
# Correct

# %%
#Checking the password using if and else.
passwrd=input("Enter the password")
passwrd1='HOPE@123'
if passwrd==passwrd1:
  print("Your password is correct")
else:
  print("Incorrect password")
# Out:
# Enter the passwordHOPE@123
# Your password is correct

# %%
Age=int(input("Age: "))
if Age<19:
  print("Children")
elif Age<40:
  print("Adult")
elif Age<59:
  print("Citizen")
else:
  print("Senior Citizen")
# Out:
# Age: 25
# Adult

# %%
#Find whether the input is positive or negtive
inp=int(input("Enter your input:"))
if inp>0:
  print("positive value")
else:
  print("Negative value")
# Out:
# Enter your input:-1
# Negative value

# %%
#Check the number is divisible by 5 or not
inp=int(input("Enter your input:"))
if inp%5==0:
  print("Divisible by 5")
else:
  print("Not Divisible by 5")
# Out:
# Enter your input:22
# Not Divisible by 5
